# %% [markdown]
# # 1- Importation des librairies

# %%
import numpy,pandas
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from copy import copy
import math

# %% [markdown]
# # Chargement du dataset

# %%
data=pandas.read_csv("sleep_data.csv")
data
# Out:
#            Date  Slept Got up  Duration  How quickly fell asleep  \
# 0    21.10.2017  23:30  05:00      5.50                      4.5
# 1    21.10.2017  11:45  12:10      0.42                      4.5
# 2    22.10.2017  23:00  05:00      6.00                      3.5
# 3    22.10.2017  06:05  09:05      3.00                      4.0
# 4    22.10.2017  14:25  15:50      1.42                      3.5
# ..          ...    ...    ...       ...                      ...
# 161  29.01.2018  00:50  05:50      5.00                      3.0
# 162  30.01.2018  00:15  05:25      5.17                      4.0
# 163  30.01.2018  06:15  08:50      2.58                      4.0
# 164  31.01.2018  00:05  05:28      5.38                      5.0
# 165  31.01.2018  08:30  09:05      0.58                      4.5
#
#      How easy got up  How felt afterwards
# 0                4.5                  4.0
# 1                3.5                  4.5
# 2                3.0                  3.0
# 3                4.5                  5.0
# 4                2.5                  4.5
# ..               ...                  ...
# 161              4.5                  4.0
# 162              4.5                  5.0
# 163              2.5                  4.0
# 164              5.0                  4.5
# 165              2.5                  5.0
#
# [166 rows x 7 columns]

# %% [markdown]
# ## Dimensions du dataset

# %%
data.shape
# Out:
# (166, 7)

# %% [markdown]
# ## Entete du dataset

# %%
data.head(5)
# Out:
#          Date  Slept Got up  Duration  How quickly fell asleep  \
# 0  21.10.2017  23:30  05:00      5.50                      4.5
# 1  21.10.2017  11:45  12:10      0.42                      4.5
# 2  22.10.2017  23:00  05:00      6.00                      3.5
# 3  22.10.2017  06:05  09:05      3.00                      4.0
# 4  22.10.2017  14:25  15:50      1.42                      3.5
#
#    How easy got up  How felt afterwards
# 0              4.5                  4.0
# 1              3.5                  4.5
# 2              3.0                  3.0
# 3              4.5                  5.0
# 4              2.5                  4.5

# %% [markdown]
# # 2- Analyses statistiques

# %% [markdown]
# ## Nombre de jours d'observation

# %%
data['Date'].value_counts()
# Out:
# 08.11.2017    3
# 23.12.2017    3
# 26.10.2017    3
# 09.12.2017    3
# 22.10.2017    3
#              ..
# 10.11.2017    1
# 30.11.2017    1
# 01.01.2018    1
# 02.01.2018    1
# 11.12.2017    1
# Name: Date, Length: 103, dtype: int64

# %%
distinct_dates_length=len(data['Date'].unique())
distinct_dates_length
# Out:
# 103

# %% [markdown]
# ## Statistiques sur la durée de sommeil

# %%
data['Duration'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Duration'].min()
# Out:
# 0.25

# %%
data['Duration'].max()
# Out:
# 10.25

# %%
data['Duration'].mean()
# Out:
# 4.222228915662652

# %% [markdown]
# # 3- Modélisation de la journée

# %% [markdown]
# ## A- Test des méthodes

# %% [markdown]
# ### Récupération des heures pour la première observation

# %%
time1=data.loc[0,'Slept']
time1
# Out:
# '23:30'

# %%
time2=data.loc[0,'Got up']
time2
# Out:
# '05:00'

# %% [markdown]
# ### Traduction en synthaxe datetime Python

# %%
t1 = datetime.strptime(time1, "%H:%M")
print('Start time:', t1.time())
# Out:
# Start time: 23:30:00

# %%
t2 = datetime.strptime(time2, "%H:%M")
print('End time:', t2.time())
# Out:
# End time: 05:00:00

# %% [markdown]
# ### Comparaion des deux temps

# %%
t1 == t2
# Out:
# False

# %% [markdown]
# ### Différences en secondes des deux temps

# %%
diff=t1-t2
diff
# Out:
# datetime.timedelta(seconds=66600)

# %%
diff.total_seconds()
# Out:
# 66600.0

# %% [markdown]
# ### Ajout de secondes au temps

# %% [markdown]
# 15min = 900secondes

# %%
_15min=timedelta(seconds=900)
_15min
# Out:
# datetime.timedelta(seconds=900)

# %%
start = datetime.strptime('00:00', "%H:%M")
print('Start :', start.time())
# Out:
# Start : 00:00:00

# %%
end = start + _15min
print('End :', end.time())
# Out:
# End : 00:15:00

# %% [markdown]
# ## B- Création et initialisation du tableau initial

# %%
start = datetime.strptime('00:00', "%H:%M")
print('Start :', start.time())
# Out:
# Start : 00:00:00

# %% [markdown]
# ### Création

# %%
journee=[]
currently = start

# %% [markdown]
# ### Initialisation

# %%
_min=1
_sec=timedelta(seconds=_min*60)

total_sec=0
while (total_sec < 86400):
    journee.append([currently, total_sec,0])
    currently += _sec
    
    total_sec += _sec.total_seconds()

# %%
len(journee)
# Out:
# 1440

# %% [markdown]
# ## C- Algorithme

# %%
for i in range(data.shape[0]):
    time1=data.loc[i,'Slept']
    time2=data.loc[i,'Got up'] 
    
    #Recupérer les temps en secondes avec comme reférence 00:00
    t0 = datetime.strptime('00:00', "%H:%M")
    t1 = (datetime.strptime(time1, "%H:%M") - t0).total_seconds()
    t2 = (datetime.strptime(time2, "%H:%M") - t0).total_seconds()
    
    #Cas où par exemple il s'endort à 23:30 et se reveille à 00:05, on doit mettre t2 dans la journée suivante
    if(t2 < t1):
        t2+=86400
    
    #Parcours de notre discrétisation de journée
    for j in range(len(journee)):
        
        #Recupérer la minute en secondes avec comme reférence 00:00
        journee_sec = (journee[j][0] - t0).total_seconds()
        
        #Prendre les journee_sec dans l'intervalle compris en t1 et t2
        #Et penser également aux:
        #Cas où t2 est dans la journée suivante, on doit prendre en compte les journee_sec dans la journee qui suit
        if((journee_sec >= t1 and journee_sec <= t2) or (journee_sec + 86400 >= t1 and journee_sec + 86400 <= t2) ):
                journee[j][2] += 1

# %% [markdown]
# ### Conversion du résultat en tableau numpy

# %%
data2=numpy.array(journee)

#On va garder les deux dernières colonnes et laisser le dataetime
data2=data2[:,1:]

# %%
data2
# Out:
# array([[0, 77],
#        [60.0, 77],
#        [120.0, 77],
#        ...,
#        [86220.0, 74],
#        [86280.0, 74],
#        [86340.0, 75]], dtype=object)

# %% [markdown]
# ### Plotting

# %%
heure=data2[:,0].tolist()
occurences=data2[:,1].tolist()

plt.plot(heure, occurences)
plt.show()

# %% [markdown]
# ## C- Regression polynomiale

# %% [markdown]
# ### Modèle

# %%
modele = numpy.poly1d(numpy.polyfit(heure, occurences, 5))
print(modele)
# Out:
#            5             4             3             2
# 2.031e-21 x - 4.458e-16 x + 3.513e-11 x - 1.147e-06 x + 0.01117 x + 73.65

# %% [markdown]
# ### Plotting

# %%
plt.figure(figsize=(15,8))
axe_x = numpy.linspace(1, 86400, 86400)
plt.plot(heure, occurences)
plt.plot(axe_x, modele(axe_x), color="orange")
plt.show()

# %% [markdown]
# ## D- Optimisation

# %% [markdown]
# ### Ecriture de la fonction objectif à base des valeurs du modèle

# %%
f2=lambda x: 2.031e-21*(x**5) - 4.458e-16*(x**4) + 3.513e-11*(x**3) - 1.147e-06*(x**2) + 0.01117*(x) + 73.65

# %%
f2(40000)
# Out:
# 0.2964000000003182

# %%
plt.figure(figsize=(15,8))
axe_x = numpy.linspace(1, 86400, 86400)
plt.plot(heure, occurences)
plt.plot(axe_x, modele(axe_x), color="orange")
plt.plot(axe_x, f2(axe_x), color="green")
plt.show()

# %% [markdown]
# ### Ecriture de la fonction objectif à base du modèle lui-mm

# %%
def f(x, model_):
    resultat=0
    
    for i in range(len(model_)+1):
        x_i = model_[i]*(x**i)
        
        resultat += x_i
    
    return resultat

# %%
f(40000,modele)
# Out:
# 1.0193562579506477

# %%
plt.figure(figsize=(15,8))
axe_x = numpy.linspace(1, 86400, 86400)
plt.plot(heure, occurences)
plt.plot(axe_x, modele(axe_x), color="orange")
plt.plot(axe_x, f(axe_x,modele), color="green")
plt.show()

# %% [markdown]
# ### Optimisation avec SineCosineAlgorithm

# %%
import sys
sys.path.append("/SCA")
import SCA

# %%
solution=SCA.SCA(fonction_objectif=f, model_=modele, lb=0, ub=86399, dim_individu=1, nombreIndividus=100, Max_iter=400)
# Out:
# SCA optimise  "f"
# ["A l'iteration 0 la meilleure fitness est: -3.3014594429805584"]
# ['Le meilleur associé est: [72701.01164197]']
#
#
# ["A l'iteration 1 la meilleure fitness est: -3.3014594429805584"]
# ['Le meilleur associé est: [72701.01164197]']
#
#
# ["A l'iteration 2 la meilleure fitness est: -3.303280155005268"]
# ['Le meilleur associé est: [72594.4663829]']
#
#
# ["A l'iteration 3 la meilleure fitness est: -3.303280155005268"]
# ['Le meilleur associé est: [72594.4663829]']
#
#
# ["A l'iteration 4 la meilleure fitness est: -3.303280155005268"]
# ['Le meilleur associé est: [72594.4663829]']
#
#
# ["A l'iteration 5 la meilleure fitness est: -3.303280155005268"]
# ['Le meilleur associé est: [72594.4663829]']
#
#
# ["A l'iteration 6 la meilleure fitness est: -3.303280155005268"]
# ['Le meilleur associé est: [72594.4663829]']
#
#
# ["A l'iteration 7 la meilleure fitness est: -3.303280155005268"]
# ['Le meilleur associé est: [72594.4663829]']
#
#
# ["A l'iteration 8 la meilleure fitness est: -3.303280155005268"]
# ['Le meilleur associé est: [72594.4663829]']
#
#
# ["A l'iteration 9 la meilleure fitness est: -3.303280155005268"]
# ['Le meilleur associé est: [72594.4663829]']
#
#
# ["A l'iteration 10 la meilleure fitness est: -3.303280155005268"]
# ['Le meilleur associé est: [72594.4663829]']
#
#
# ["A l'iteration 11 la meilleure fitness est: -3.303280155005268"]
# ['Le meilleur associé est: [72594.4663829]']
#
#
# ["A l'iteration 12 la meilleure fitness est: -3.303280155005268"]
# ['Le meilleur associé est: [72594.4663829]']
#
#
# ["A l'iteration 13 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 14 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 15 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 16 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 17 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 18 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 19 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 20 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 21 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 22 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 23 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 24 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 25 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 26 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 27 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 28 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 29 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 30 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 31 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 32 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 33 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 34 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 35 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 36 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 37 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 38 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 39 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 40 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 41 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 42 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 43 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 44 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 45 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 46 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 47 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 48 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 49 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 50 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 51 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 52 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 53 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 54 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 55 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 56 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 57 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 58 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 59 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 60 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 61 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 62 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 63 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 64 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 65 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 66 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 67 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 68 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 69 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 70 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 71 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 72 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 73 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 74 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 75 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 76 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
# ["A l'iteration 77 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 78 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 79 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 80 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 81 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 82 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 83 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 84 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 85 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 86 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 87 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 88 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 89 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 90 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 91 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 92 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 93 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 94 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 95 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 96 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 97 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 98 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 99 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 100 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 101 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 102 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration 103 la meilleure fitness est: -3.3032863785510926"]
# ['Le meilleur associé est: [72599.08991591]']
#
#
# ["A l'iteration